# %%
# round serve para arrededondar o numero. o primeiro é valor que passa e o segundo é a casa de decimais
## Arredondando para 2 casas
a = 2.436
b = 12.2345678
c = -3.4443

# %%
print(round(a,2))
print(round(b,3))
print(round(c,2))
# Out:
# 2.44
# 12.235
# -3.44

# %%
#colocando em ordem crescente
dados = [3, 10, 4, 5, 6, 11, 14, 24]
dados_ord = sorted(dados)
dados_ord
# Out:
# [3, 4, 5, 6, 10, 11, 14, 24]

# %%
#Elementos.
n = len(dados)
soma = sum(dados)
media = soma/n
print("A lista tem", n, "elementos")
print("A soma dos elementos é", soma)
print("A média dos elementos é", media)
# Out:
# A lista tem 8 elementos
# A soma dos elementos é 77
# A média dos elementos é 9.625
